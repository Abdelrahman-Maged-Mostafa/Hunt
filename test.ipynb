# %% [markdown]
# <a test="true" data-html="true" class=poda>hello</a><ul class='js-breadcrumbs-list'><li><a data-html=true href='~rr'><div style='max-width:20px;font-size: 100px;' class=js-breadcrumb-item-text>AA&lt;a href=x class=plamka data-poleka=holka&gt;poda&lt;/a&gt;</div></a></li></ul>
